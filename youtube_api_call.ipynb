# %%
import pandas as pd
import requests
import numpy as np
from api_keys import api_key
from api_keys2 import api_key2

# %%
yt_file = "./youtube_files/USvideos.csv"
usvideos_df = pd.read_csv(yt_file)
usvideos_df = pd.DataFrame(usvideos_df)
usvideos_df.head()
# Out:
#       video_id trending_date  \
# 0  2kyS6SvSYSE      17.14.11
# 1  1ZAPwfrtAFY      17.14.11
# 2  5qpjK5DgCt4      17.14.11
# 3  puqaWrEC7tY      17.14.11
# 4  d380meD0W0M      17.14.11
#
#                                                title          channel_title  \
# 0                 WE WANT TO TALK ABOUT OUR MARRIAGE           CaseyNeistat
# 1  The Trump Presidency: Last Week Tonight with J...        LastWeekTonight
# 2  Racist Superman | Rudy Mancuso, King Bach & Le...           Rudy Mancuso
# 3                   Nickelback Lyrics: Real or Fake?  Good Mythical Morning
# 4                           I Dare You: GOING BALD!?               nigahiga
#
#    category_id              publish_time  \
# 0           22  2017-11-13T17:13:01.000Z
# 1           24  2017-11-13T07:30:00.000Z
# 2           23  2017-11-12T19:05:24.000Z
# 3           24  2017-11-13T11:00:04.000Z
# 4           24  2017-11-12T18:01:41.000Z
#
# ...

# %%
channels = usvideos_df['channel_title'].unique()
channels
# Out:
# array(['CaseyNeistat', 'LastWeekTonight', 'Rudy Mancuso', ...,
#        'All Def Digital', 'How It Should Have Ended',
#        'Ubisoft North America'], dtype=object)

# %%
for channel in channels:
    print(channel)
# Out:
# CaseyNeistat
# LastWeekTonight
# Rudy Mancuso
# Good Mythical Morning
# nigahiga
# iJustine
# Saturday Night Live
# CrazyRussianHacker
# 20th Century Fox
# Vox
# NFL
# amc
# marshmello
# NowThis World
# The king of DIY
# BostonDynamics
# Cracked
# TED-Ed
# PeterSripol
# SciShow
# Life Noggin
# Tested
# Tom Scott
# Refinery29
# Gus Johnson
# HellthyJunkFood
# Numberphile
# JerryRigEverything
# Cleveland Cavaliers on cleveland.com
# FaeryInLoveInc
# hp_overload
# Amazon.co.uk
# EminemVEVO
# officer401
# Emirates
# Nobrand
# Screen Junkies
# Hunter Hayes
# Niki and Gabi
# Nickelback
# U2VEVO
# BBC News
# Ben Rohrbach
# MatthewSantoro
# Shawn Johnson East
# dope2111
# People are Awesome
# NBA Highlights · YouTube
# D3sports.com
# FBE
# Simply Nailogical
# CBS Sunday Morning
# WWE
# JenniferLopezVEVO
# Grace Helbig
# The Graham Norton Show
# Kevin Durant
# JimBrowski 96HourNews
# ViralHog
# Jeremy Jahns
# Jonathan Morrison
# TIME
# YouTube Spotlight
# GEazyMusicVEVO
# U.S. Navy
# IGN
# ...

# %%
#testing to see if my api call returns the information I need. 
url1 = "https://www.googleapis.com/youtube/v3/channels" 

response_url = url1 + "?part=statistics" + "&forUsername=" + 'Cracked' + "&key=" + api_key2 
print(response_url)
# Out:
# https://www.googleapis.com/youtube/v3/channels?part=statistics&forUsername=Cracked&key=AIzaSyAtV3cLgdF_XAHJtUi2OZDELyCnmNSMKWo

# %%
youtube_channel = []
channel_id = []
subscriber_count = []
view_count = []
comment_count = []

count = 0

for channel in channels:
    response_url = url1 + "?part=statistics" + "&forUsername=" + channel + "&key=" + api_key2
    
    try:
        response = requests.get(response_url).json()
        youtube_channel.append(channel)
        channel_id.append(response['items'][0]['id']) 
        view_count.append(response['items'][0]['statistics']['viewCount']) 
        subscriber_count.append(response['items'][0]['statistics']['subscriberCount'])
        comment_count.append(response['items'][0]['statistics']['commentCount'])
        print(f"channel {channel}")
        count = count + 1 
    
    except:
        print("not found")
    continue
# Out:
# channel CaseyNeistat
# channel LastWeekTonight
# not found
# not found
# channel nigahiga
# channel iJustine
# not found
# channel CrazyRussianHacker
# not found
# channel Vox
# channel NFL
# channel amc
# not found
# not found
# not found
# channel BostonDynamics
# channel Cracked
# not found
# not found
# channel SciShow
# not found
# not found
# not found
# not found
# not found
# channel HellthyJunkFood
# channel Numberphile
# channel JerryRigEverything
# not found
# channel FaeryInLoveInc
# not found
# not found
# channel EminemVEVO
# channel officer401
# channel Emirates
# channel Nobrand
# not found
# not found
# not found
# not found
# channel U2VEVO
# not found
# not found
# channel MatthewSantoro
# not found
# channel dope2111
# not found
# not found
# not found
# not found
# not found
# not found
# channel WWE
# channel JenniferLopezVEVO
# not found
# not found
# not found
# not found
# channel ViralHog
# not found
# not found
# channel TIME
# not found
# ...

# %%
response_dict = {
    "channel_name": youtube_channel,
    "channel_id": channel_id,
    "subscriber count": subscriber_count, 
    "view count": view_count,
    "comment count": comment_count
}

# %%
# when I originally tried creating the dataframe from the dictionaries I appended I 
#got ValueError: arrays must all be same length. I used this function which pads the rows with no values. 
# I am using this in conjuction with the transpose() to get my dataframe. Using either one does not seem to work, 
# they have to be paired together to get the dataframe. I found this weird. 

def pad_dict_list(response_dict):
    lmax = 0
    for lname in dict_list.keys():
        lmax = max(lmax, len(response_dict[lname]))
    for lname in response_dict.keys():
        ll = len(response_dict[lname])
        if  ll < lmax:
            response_dict[lname] += [padel] * (lmax - ll)
    return dict_list

# %%
youtube_channel_statistics= pd.DataFrame.from_dict(response_dict, orient= "index")
youtube_channel_statistics = youtube_channel_statistics.transpose()
youtube_channel_statistics.head()
# Out:
#             channel_name                channel_id subscriber count  \
# 0           CaseyNeistat  UCtinbF-Q-fVthA0qrFQTgXQ         11426855
# 1        LastWeekTonight  UC3XTzVzaHQEd30rQbuvCtTQ          7123378
# 2           Rudy Mancuso  UCSAUGyc_xA8uYzaIVG6MESQ         21395599
# 3  Good Mythical Morning  UCey_c7U86mJGz1VJWH5CYPA          5932900
# 4               nigahiga  UCe_vXdMrHHseZ_esYUskSBw         11166370
#
#    view count comment count
# 0  2623412835             0
# 1  2067766550             0
# 2  4087135518             0
# 3  1048655939             0
# 4  2627331842             0

# %%
# when I called the api it seemed like comment count was not appended. I can't make more calls since i exceeded my limit. 
# I am dropping the column instead. 

youtube_channel_statistics = youtube_channel_statistics.drop(["comment count"], axis=1)
youtube_channel_statistics.head()
# Out:
#             channel_name                channel_id subscriber count  \
# 0           CaseyNeistat  UCtinbF-Q-fVthA0qrFQTgXQ         11426855
# 1        LastWeekTonight  UC3XTzVzaHQEd30rQbuvCtTQ          7123378
# 2           Rudy Mancuso  UCSAUGyc_xA8uYzaIVG6MESQ         21395599
# 3  Good Mythical Morning  UCey_c7U86mJGz1VJWH5CYPA          5932900
# 4               nigahiga  UCe_vXdMrHHseZ_esYUskSBw         11166370
#
#    view count
# 0  2623412835
# 1  2067766550
# 2  4087135518
# 3  1048655939
# 4  2627331842

# %%
#dropping the null values since in our sql database our tables have the not null parameter. 
youtube_channel_statistics_df = youtube_channel_statistics.dropna()
youtube_channel_statistics_df.head()
# Out:
#             channel_name                channel_id subscriber count  \
# 0           CaseyNeistat  UCtinbF-Q-fVthA0qrFQTgXQ         11426855
# 1        LastWeekTonight  UC3XTzVzaHQEd30rQbuvCtTQ          7123378
# 2           Rudy Mancuso  UCSAUGyc_xA8uYzaIVG6MESQ         21395599
# 3  Good Mythical Morning  UCey_c7U86mJGz1VJWH5CYPA          5932900
# 4               nigahiga  UCe_vXdMrHHseZ_esYUskSBw         11166370
#
#    view count
# 0  2623412835
# 1  2067766550
# 2  4087135518
# 3  1048655939
# 4  2627331842

# %%
#checking for datatypes so we can make the table in sql 
youtube_channel_statistics_df.dtypes
# Out:
# channel_name        object
# channel_id          object
# subscriber count    object
# view count          object
# dtype: object

# %%
#youtube_channel_statistics_df['view count'] = pd.to_numeric(youtube_channel_statistics_df['view count'],errors='coerce')
#youtube_channel_statistics_df['subscriber count'] = pd.to_numeric(youtube_channel_statistics_df['subscriber count'],errors='coerce')
#did not use this because it gave me floats instead of int32 which is the same format in the other csv file I have. 

columns = ['view count', 'subscriber count']
for column in columns:
    youtube_channel_statistics_df[column] = youtube_channel_statistics_df[column].astype(int)

# %%
youtube_channel_statistics_df.dtypes

#in sql or pandas we can merge the datasets together with the channel_name column.
# Out:
# channel_name        object
# channel_id          object
# subscriber count     int32
# view count           int32
# dtype: object

# %%
youtube_channel_statistics_df.to_csv(r'C:\Users\Jose\Documents\youtube_etl_project\usa_channel_statistics.csv')
